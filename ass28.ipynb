# %% [raw]
# #Q1.
#
# The three measures of central tendency are:
#
#     Mean: The mean is the sum of all values in a data set divided by the total number of values. It represents the "average" value of the data.
#
#     Median: The median is the middle value in a sorted data set. To find the median, you arrange the data in ascending (or descending) order and choose the middle value. If there is an even number of values, the median is the average of the two middle values.
#
#     Mode: The mode is the value that appears most frequently in a data set. There can be one mode (unimodal) or multiple modes (multimodal), or no mode at all if all values have the same frequency.
#
# These measures provide insights into the central or typical value of a data set and help describe its distribution. Each measure has its strengths and weaknesses, and the choice of which to use depends on the nature of the data and the specific context of the analysis.

# %% [raw]
# #Q2.
#
# Mean, median, and mode are three different measures of central tendency used to describe the "typical" or central value of a dataset. They each provide different insights into the distribution of the data and are used in various contexts depending on the nature of the data and the analysis being conducted.
#
#     Mean:
#     The mean, often referred to as the average, is calculated by adding up all the values in a dataset and then dividing by the number of values. Mathematically, it can be represented as:
#
# Mean = (Sum of all values) / (Number of values)
#
# The mean is sensitive to extreme values, also known as outliers. If there are outliers in the dataset, they can significantly impact the mean, pulling it in their direction. The mean is commonly used when the data is symmetrically distributed and doesn't have significant outliers.
#
#     Median:
#     The median is the middle value in a dataset when the values are arranged in ascending or descending order. If there's an odd number of values, the median is the middle value. If there's an even number of values, the median is the average of the two middle values. The median is less affected by extreme values compared to the mean, making it a better choice when dealing with skewed data or datasets containing outliers.
#
#     Mode:
#     The mode is the value that appears most frequently in a dataset. A dataset can have one mode (unimodal), two modes (bimodal), or more (multimodal). The mode is useful for describing the most common value in a dataset, especially when dealing with categorical or discrete data.
#
# In summary, the differences between the mean, median, and mode are:
#
#     Sensitivity to Outliers:
#         Mean: Sensitive to outliers.
#         Median: Less sensitive to outliers.
#         Mode: Not affected by outliers.
#
#     Calculation Method:
#         Mean: Calculated by summing all values and dividing by the number of values.
#         Median: Middle value in an ordered dataset.
#         Mode: Most frequently occurring value.
#
#     Applicability:
#         Mean: Suitable for symmetrically distributed data without significant outliers.
#         Median: Suitable for skewed data or data with outliers.
#         Mode: Suitable for categorical or discrete data.
#
# When choosing which measure of central tendency to use, it's important to consider the nature of the data and the goals of the analysis. Sometimes, it might be useful to report multiple measures to provide a more complete picture of the data's central tendency.

# %% [raw]
# #Q3.
#
# The three measures of central tendency are the mean, median, and mode. Let's calculate each of them for the given height data:
#
# Data: [178, 177, 176, 177, 178.2, 178, 175, 179, 180, 175, 178.9, 176.2, 177, 172.5, 178, 176.5]
#
#     Mean:
#     Mean = (Sum of all values) / (Number of values)
#     Mean = (178 + 177 + 176 + 177 + 178.2 + 178 + 175 + 179 + 180 + 175 + 178.9 + 176.2 + 177 + 172.5 + 178 + 176.5) / 16
#     Mean ≈ 176.9438
#
#     Median:
#     To find the median, first, we need to arrange the data in ascending order:
#     172.5, 175, 175, 176, 176, 176.2, 176.5, 177, 177, 177, 178, 178, 178, 178.2, 178.9, 179, 180
#
# Since there are 16 data points, the median will be the average of the 8th and 9th values (middle two values):
# Median = (177 + 177) / 2
# Median = 177
#
#     Mode:
#     The mode is the value that appears most frequently in the data set. In this case, the value 178 appears the most times (four times), making it the mode.
#
# So, for the given height data:
#
#     Mean ≈ 176.9438
#     Median = 177
#     Mode = 178

# %% [raw]
# #Q4.
#
# To calculate the standard deviation for the given data, you can follow these steps:
#
#     Find the mean (average) of the data.
#     Calculate the squared difference between each data point and the mean.
#     Find the mean of the squared differences.
#     Take the square root of the mean of squared differences to get the standard deviation.
#
# Let's calculate it step by step:
#
#     Mean (average):
#     Mean = (178 + 177 + 176 + 177 + 178.2 + 178 + 175 + 179 + 180 + 175 + 178.9 + 176.2 + 177 + 172.5 + 178 + 176.5) / 16
#     Mean = 177.8625
#
#     Squared differences from the mean:
#     (178 - 177.8625)^2 = 0.01800625
#     (177 - 177.8625)^2 = 0.0076125
#     (176 - 177.8625)^2 = 3.5430625
#     ...
#     (178 - 177.8625)^2 = 0.01800625
#     (176.5 - 177.8625)^2 = 1.84700625
#
#     Mean of squared differences:
#     Mean of squared differences = (0.01800625 + 0.0076125 + 3.5430625 + ... + 0.01800625 + 1.84700625) / 16
#     Mean of squared differences ≈ 3.9685734375
#
#     Standard deviation:
#     Standard deviation = √(Mean of squared differences)
#     Standard deviation ≈ √(3.9685734375)
#     Standard deviation ≈ 1.992131988
#
# So, the approximate standard deviation for the given data is 1.992.

# %% [raw]
# #Q5.
#
# Measures of dispersion, including range, variance, and standard deviation, are used to quantify how spread out or dispersed the values in a dataset are. They provide insights into the variability or consistency of the data points, helping to understand the degree to which data points deviate from the central tendency (mean, median, mode).
#
#     Range: The range is the simplest measure of dispersion and is calculated as the difference between the maximum and minimum values in a dataset. It provides a basic understanding of the spread but is sensitive to outliers and doesn't consider the distribution of data points between the two extremes.
#
#     Example: Consider the following ages of a group of individuals: 25, 27, 30, 32, 35. The range is calculated as 35 - 25 = 10, indicating that the age values are spread over a range of 10 years.
#
#     Variance: Variance measures the average squared deviation of each data point from the mean of the dataset. A higher variance indicates greater variability, while a lower variance suggests less variability.
#
#     Example: Let's use the same ages as before: 25, 27, 30, 32, 35. First, calculate the mean: (25 + 27 + 30 + 32 + 35) / 5 = 29.8. Then calculate the squared differences from the mean for each data point: (25 - 29.8)^2, (27 - 29.8)^2, (30 - 29.8)^2, (32 - 29.8)^2, (35 - 29.8)^2. Calculate the average of these squared differences: (41.64 + 7.84 + 0.04 + 7.84 + 25.24) / 5 = 16.12. This is the variance of the dataset.
#
#     Standard Deviation: The standard deviation is the square root of the variance. It provides a more intuitive measure of dispersion in the same units as the original data. A larger standard deviation indicates more spread-out data, while a smaller standard deviation indicates data that is closer to the mean.
#
#     Example: Using the variance example above, the variance was calculated as 16.12. The standard deviation is the square root of the variance, so the standard deviation is √16.12 ≈ 4.01.
#
# In the context of the age example, a range of 10 years indicates the spread of ages, a variance of 16.12 provides a measure of the average squared deviation from the mean age, and a standard deviation of approximately 4.01 tells you how dispersed the ages are around the mean in the same unit (years).
#
# These measures are particularly useful when comparing different datasets or when trying to understand the variability within a single dataset. They help in making informed decisions, identifying outliers, and gaining insights into the distribution of data points.

# %% [raw]
# #Q6.
#
# A Venn diagram is a graphical representation that uses circles or other shapes to illustrate the relationships between different sets, groups, or categories. It was introduced by the mathematician John Venn in the late 19th century. Venn diagrams are commonly used to depict the overlap and differences between two or more sets of items, elements, or concepts.
#
# Each circle in a Venn diagram represents a set, and the areas where the circles overlap indicate the elements that belong to multiple sets. The non-overlapping areas represent the elements that are unique to each individual set.
#
# Venn diagrams are often used in various fields, including mathematics, logic, statistics, and various academic disciplines, as well as in everyday situations to visually represent and analyze relationships and comparisons between different entities or concepts. They provide a simple and intuitive way to convey complex information and relationships through visualization.

# %% [raw]
# #Q7.
#
# It seems there might be a little confusion in the notation. Sets are usually represented with curly braces { } rather than parentheses ( ). I'll assume you meant the sets A = {2, 3, 4, 5, 6, 7} and B = {0, 2, 6, 8, 10}.
#
# (i) A ∩ B (the intersection of sets A and B) is the set of elements that are common to both A and B.
#
# A ∩ B = {2, 6}
#
# (ii) A ⋃ B (the union of sets A and B) is the set of all elements that belong to either A or B or both.
#
# A ⋃ B = {0, 2, 3, 4, 5, 6, 7, 8, 10}
#
# So, to summarize:
# (i) A ∩ B = {2, 6}
# (ii) A ⋃ B = {0, 2, 3, 4, 5, 6, 7, 8, 10}

# %% [raw]
# #Q8.
#
# Skewness is a statistical measure that describes the asymmetry of the probability distribution of a real-valued random variable. In simpler terms, it helps us understand the shape of a data distribution.
#
# There are three types of skewness:
#
#     Positive Skewness (Right Skewness): In a positively skewed distribution, the tail on the right side is longer or fatter than the left side. This means that the majority of the data values are clustered on the left side of the distribution, with a few larger values pulling the mean to the right.
#
#     Example: Income distribution in a population where a few individuals earn significantly higher incomes than the majority.
#
#     Negative Skewness (Left Skewness): In a negatively skewed distribution, the tail on the left side is longer or fatter than the right side. This indicates that the bulk of the data values are concentrated on the right side of the distribution, with a few smaller values dragging the mean to the left.
#
#     Example: Test scores in a relatively easy exam where most students score well but a few students perform very poorly.
#
#     Symmetrical Distribution (Zero Skewness): A symmetrical distribution has equal tails on both sides, and the mean, median, and mode are all at the same point. In this case, the skewness value is close to zero.
#
# Skewness is an important concept in statistics and data analysis because it provides insights into the distribution of data and can impact various statistical analyses and modeling techniques. It's worth noting that while skewness provides information about the shape of the distribution, it doesn't necessarily indicate the presence of outliers or the overall spread of the data.

# %% [raw]
# #Q9.
#
# In a right-skewed distribution (also known as positively skewed), the tail of the distribution is stretched out to the right, meaning that there are relatively few data points with high values, but a few very high values that pull the mean in that direction. The median, on the other hand, is less affected by extreme values and is more robust to outliers.
#
# In a right-skewed distribution:
#
#     The mean will be greater than the median.
#     The median will typically be closer to the left (lower) end of the distribution, where the majority of the data points are concentrated.
#
# This is because the presence of a few extremely high values in the right tail of the distribution pulls the mean in that direction, while the median remains relatively unaffected by these extreme values, maintaining a position closer to the main cluster of data points.
#
# In summary, in a right-skewed distribution, the median is generally to the left of the mean.

# %% [raw]
# #Q10.
#
#
# Covariance and correlation are both measures that describe the relationship between two variables in a statistical context, particularly in multivariate data analysis. They provide insights into how changes in one variable relate to changes in another variable. However, they have distinct characteristics and are used for different purposes.
#
#     Covariance:
#     Covariance measures the degree to which two variables vary together. In other words, it quantifies the extent to which changes in one variable correspond to changes in another variable. If the covariance is positive, it suggests that both variables tend to increase or decrease together. If the covariance is negative, it suggests that when one variable increases, the other tends to decrease.
#
# The formula for calculating the covariance between two variables X and Y, given a set of data points, is:
#
# Cov(X,Y)=∑(xi−Xˉ)(yi−Yˉ)n−1Cov(X,Y)=n−1∑(xi​−Xˉ)(yi​−Yˉ)​
#
# Where:
#
#     xixi​ and yiyi​ are individual data points of variables X and Y, respectively.
#     XˉXˉ and YˉYˉ are the means of variables X and Y, respectively.
#     nn is the number of data points.
#
# Covariance is a raw measure and its magnitude is not standardized, which makes it difficult to compare across different datasets. Its units are the product of the units of the two variables being compared.
#
#     Correlation:
#     Correlation is a standardized version of covariance that provides a more interpretable measure of the relationship between two variables. It quantifies both the strength and the direction of the linear relationship between two variables. Correlation ranges from -1 to 1. A correlation of +1 indicates a perfect positive linear relationship, a correlation of -1 indicates a perfect negative linear relationship, and a correlation of 0 indicates no linear relationship.
#
# The most common measure of correlation is the Pearson correlation coefficient (r), which is calculated using the formula:
#
# r=Cov(X,Y)sX⋅sYr=sX​⋅sY​Cov(X,Y)​
#
# Where:
#
#     Cov(X,Y)Cov(X,Y) is the covariance between variables X and Y.
#     sXsX​ and sYsY​ are the standard deviations of variables X and Y, respectively.
#
# Correlation standardizes the covariance by dividing it by the product of the standard deviations of the two variables, making it independent of the scale and unit of measurement of the variables. This allows for easier comparison and interpretation of the relationship between variables.
#
# Usage in Statistical Analysis:
# Covariance and correlation are used in various statistical and data analysis tasks:
#
#     Relationship Assessment: Covariance and correlation help quantify the degree and nature of the relationship between two variables. They provide insights into whether the variables tend to move together, move in opposite directions, or have no apparent relationship.
#
#     Feature Selection: In feature selection for machine learning and data modeling, correlation is often used to identify relevant features that are strongly correlated with the target variable.
#
#     Portfolio Management: In finance, covariance and correlation are used to analyze the relationship between different assets within a portfolio. Lower correlation between assets can help diversify risk.
#
#     Experimental Design: Covariance and correlation analysis can be used to assess the impact of experimental factors on different variables.
#
#     Quality Control: In manufacturing and quality control, these measures can be used to analyze how changes in one variable affect another and identify potential sources of variability.
#
#     Econometrics: Covariance and correlation are essential tools in studying economic relationships, such as analyzing the relationship between variables like income and expenditure.
#
# In summary, covariance and correlation provide valuable insights into the relationships between variables, with correlation offering a standardized measure that is easier to interpret and compare. Both measures play a crucial role in understanding data patterns and making informed decisions in various fields of study.

# %% [raw]
# #Q11.
#
# The sample mean, often denoted by "x̄" (pronounced as "x-bar"), is the average of a set of numerical values in a dataset. The formula for calculating the sample mean is:
#
# Sample Mean (xˉ)=Sum of all values in the datasetNumber of values in the dataset/Number of values in the datasetSum of all values in the dataset​
#
# Here's an example calculation:
#
# Suppose you have the following dataset of exam scores: {85, 92, 78, 88, 95}. To calculate the sample mean:
#
# Sample Mean (xˉ)=85+92+78+88+95/5=438/5=87.6
#
# So, the sample mean of the exam scores is 87.6.

# %% [raw]
# #Q12.
#
# In a normal distribution, also known as a Gaussian distribution, the measures of central tendency (i.e., the values that represent the center or typical value of the data) are all the same. This is a unique characteristic of the normal distribution and one of the reasons why it is so widely used in statistics and data analysis.
#
# The three main measures of central tendency are the mean, median, and mode. In a normal distribution:
#
#     Mean: The mean of a normal distribution is located at its center. It is the arithmetic average of all the data points and is denoted by μ (mu).
#
#     Median: The median of a normal distribution is also located at its center. It is the middle value when the data points are arranged in ascending order. In a symmetric normal distribution, the median is equal to the mean.
#
#     Mode: The mode of a normal distribution is the value that occurs most frequently. In a normal distribution, all values have the same frequency, so there is no single mode. Technically, every value in the distribution is a mode.
#
# Mathematically, these measures are equal in a true normal distribution. However, in real-world data, due to sampling variability or other factors, slight differences between the mean, median, and mode can occur. These differences are more likely to be observed in smaller sample sizes or when dealing with data that has outliers or non-normal characteristics.
#
# In summary, for a perfect normal distribution, the mean, median, and mode are all located at the center of the distribution and are equal.

# %% [raw]
# #Q13.
#
# Covariance and correlation are both measures used in statistics to describe the relationship between two variables. While they are related concepts, they have some key differences:
#
#     Definition:
#         Covariance: Covariance measures the degree to which two variables change together. It indicates whether an increase in one variable corresponds to an increase or decrease in another variable.
#         Correlation: Correlation measures the strength and direction of the linear relationship between two variables. It is a standardized measure that ranges between -1 and 1, where -1 indicates a perfect negative linear relationship, 1 indicates a perfect positive linear relationship, and 0 indicates no linear relationship.
#
#     Scale:
#         Covariance: The value of covariance is not standardized and depends on the units of the variables. As a result, it can be difficult to interpret the magnitude of covariance.
#         Correlation: Correlation is standardized, which means it is unitless and can be easily interpreted. It gives a clearer understanding of the strength and direction of the relationship between the variables.
#
#     Range of Values:
#         Covariance: Covariance can take any real value, including positive, negative, and zero.
#         Correlation: Correlation always ranges between -1 and 1, providing a more consistent measure of the strength and direction of the relationship.
#
#     Interpretation:
#         Covariance: A positive covariance indicates that the variables tend to increase together, while a negative covariance indicates that one variable tends to increase as the other decreases. A covariance close to zero suggests little to no linear relationship between the variables.
#         Correlation: Correlation provides a more intuitive interpretation. A positive correlation indicates a strong tendency for the variables to increase together, a negative correlation indicates a strong tendency for one variable to decrease as the other increases, and a correlation close to zero suggests a weak or no linear relationship.
#
#     Standardization:
#         Covariance: Covariance is not standardized, which can make it challenging to compare the relationships between different pairs of variables.
#         Correlation: Correlation is standardized, making it easier to compare and analyze the relationships between different pairs of variables.
#
# In summary, while both covariance and correlation provide information about the relationship between two variables, correlation is often preferred in practice due to its standardized nature, clear interpretation, and ability to compare relationships across different pairs of variables.

# %% [raw]
# #Q14.
#
#
# Outliers can have a significant impact on measures of central tendency and dispersion in a dataset. Measures of central tendency, such as the mean, median, and mode, provide an idea of the "typical" or "average" value in a dataset, while measures of dispersion, such as the range, variance, and standard deviation, indicate how spread out the values are from the central point.
#
# Impact on Measures of Central Tendency:
#
#     Mean: Outliers can heavily influence the mean since it takes into account all values in the dataset. Even a single extreme outlier can significantly skew the mean towards its direction.
#
# Example: Consider a dataset representing the incomes (in thousands) of a group of people: {30, 35, 40, 45, 50, 100}. The outlier value 100 is much larger than the other values, and including it in the mean calculation would yield a mean income of (30 + 35 + 40 + 45 + 50 + 100) / 6 = 50.83, which overestimates the typical income due to the outlier.
#
#     Median: Outliers have less impact on the median compared to the mean. The median is the middle value when the data is ordered, so extreme outliers affect it less.
#
# Example: Using the same dataset as above, the median would be the middle value, which is 42.5. The outlier value 100 doesn't have as strong an influence on the median as it did on the mean.
#
#     Mode: The mode represents the most frequently occurring value in the dataset. Outliers typically do not affect the mode unless they occur frequently.
#
# Impact on Measures of Dispersion:
#
#     Range: The range is sensitive to outliers as it's simply the difference between the maximum and minimum values. Even a single outlier can drastically change the range.
#
# Example: In the dataset {30, 35, 40, 45, 50, 100}, the range without the outlier is 100 - 30 = 70, but including the outlier increases the range to 100 - 30 = 70.
#
#     Variance and Standard Deviation: Both variance and standard deviation are affected by outliers, as they involve squaring the differences between each data point and the mean. Outliers can lead to a larger spread of squared differences, resulting in higher values for variance and standard deviation.
#
# Example: Using the same dataset, calculating the variance and standard deviation with the outlier results in higher values compared to when the outlier is removed, indicating increased dispersion.
#
# In summary, outliers can distort measures of central tendency, particularly the mean, and can inflate measures of dispersion, such as range, variance, and standard deviation. It's important to identify and handle outliers appropriately, depending on the context and goals of your analysis.
